# %% [markdown]
# <a href="https://colab.research.google.com/github/Killingjoke1797/Killingjoke1797/blob/main/Misiones_Alterno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Misión 1***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr, kendalltau, spearmanr

# %%
data = pd.read_csv('dataset_renovables_con_errores.csv')
data
# Out:
#     Planta Energética  Tipo de Energía Nivel de Democratización Energética  \
# 0           SolarFlow            Solar                                Alto
# 1             SunWave            Solar                                Bajo
# 2             EcoWind              NaN                                Bajo
# 3           SolarFlow       Geotérmica                                 NaN
# 4           HydroFlux  Hidrógeno verde                               Medio
# ..                ...              ...                                 ...
# 995           EcoWind  Hidrógeno verde                                Bajo
# 996           Solaris           Eólica                               Medio
# 997           SunWave           Eólica                                Bajo
# 998       VientoVerde           Eólica                                Bajo
# 999         HydroFlux           Eólica                               Medio
#
# ...

# %%
data.describe()
# Out:
#        Número de Proyectos en Marcha  Costo de Producción ($/MW)  \
# count                     810.000000                 1000.000000
# mean                       10.262963                 2620.846302
# std                         5.447467                  653.454384
# min                         1.000000                 1542.598865
# 25%                         6.000000                 2044.109301
# 50%                        10.000000                 2620.846302
# 75%                        15.000000                 3197.583303
# max                        19.000000                 3749.244782
#
#        Año de Instalación  Rentabilidad en 10 años (Rentable=1, No Rentable=0)
# count         1000.000000                                         1000.00000
# mean          2012.175000                                            0.58400
# std              5.605872                                            0.49314
# ...

# %%
data.dtypes
# Out:
# Planta Energética                                       object
# Tipo de Energía                                         object
# Nivel de Democratización Energética                     object
# Número de Comunidades Energéticas                       object
# Número de Proyectos en Marcha                          float64
# Capacidad Generada (MW)                                 object
# Reducción de CO2 (toneladas)                            object
# Región                                                  object
# Costo de Producción ($/MW)                             float64
# Año de Instalación                                       int64
# Rentabilidad en 10 años (Rentable=1, No Rentable=0)      int64
# dtype: object

# %% [markdown]
# Tratamiento para Planta energética

# %%
data['Rentabilidad en 10 años (Rentable=1, No Rentable=0)'].value_counts()
# Out:
# Rentabilidad en 10 años (Rentable=1, No Rentable=0)
# 1    584
# 0    416
# Name: count, dtype: int64

# %%
#reemplaza los (@#$, error) por valores nulos
data.replace(['@#$', 'error'], np.nan, inplace=True)

# %%
data.isnull().sum() #conteo
# Out:
# Planta Energética                                        5
# Tipo de Energía                                         78
# Nivel de Democratización Energética                    106
# Número de Comunidades Energéticas                        5
# Número de Proyectos en Marcha                          190
# Capacidad Generada (MW)                                178
# Reducción de CO2 (toneladas)                            61
# Región                                                  62
# Costo de Producción ($/MW)                               0
# Año de Instalación                                       0
# Rentabilidad en 10 años (Rentable=1, No Rentable=0)      0
# dtype: int64

# %% [markdown]
# Tratamiento para tipo de energía

# %%
data['Tipo de Energía'].value_counts()
# Out:
# Tipo de Energía
# Solar              194
# Hidráulica         193
# Geotérmica         188
# Eólica             188
# Hidrógeno verde    159
# Name: count, dtype: int64

# %%
data['Número de Comunidades Energéticas'].value_counts()
# Out:
# Número de Comunidades Energéticas
# 45    30
# 49    30
# 21    30
# 41    29
# 38    28
# 15    28
# 17    28
# 12    27
# 8     27
# 32    26
# 40    26
# 27    25
# 36    24
# 5     24
# 23    24
# 25    23
# 33    23
# 22    23
# 48    23
# 28    23
# 31    22
# 7     22
# 39    22
# 42    22
# 44    22
# 30    22
# 26    21
# 43    21
# 16    20
# 34    20
# 47    20
# 24    20
# 10    19
# 14    19
# 9     18
# 13    18
# 20    17
# 35    17
# 29    17
# 18    16
# 19    16
# 46    16
# 37    16
# 6     16
# 11    15
# Name: count, dtype: int64

# %%
ntabla = data
media = data['Número de Comunidades Energéticas'].mean()[0]
media
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d7411c45236e> in <cell line: 2>()
#       1 ntabla = data
# ----> 2 media = data['Número de Comunidades Energéticas'].mean()[0]
#       3 media
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6223         **kwargs,
#    6224     ):
# -> 6225         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6226
#    6227     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# ...

# %%
correlacion = data['Número de Comunidades Energéticas', 'Número de Proyectos Renovables', 'Capacidad Generada(MW)','Reducción ']

# %%
moda = ntabla['Tipo de Energía'].mode()[0]
moda
ntabla['Planta Energética'].fillna(moda, inplace = True)
ntabla['Planta Energética'].isnull().sum()
# Out:
# 0

# %%
moda = ntabla['Nivel de Democratización Energética'].mode()[0]
moda

ntabla['Nivel de Democratización Energética'].fillna(moda, inplace = True)
ntabla['Nivel de Democratización Energética'].isnull().sum()
# Out:
# 'Medio'
